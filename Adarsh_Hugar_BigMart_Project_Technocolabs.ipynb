# %% [markdown]
# ### Installing libraries

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# !pip install xgboost

# %% [markdown]
# ### Importing libraries

# %%
# Essential libraries 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Importing dataset

# %%
# As the given file is at CSV format,

my_data = pd.read_csv(r'C:\Users\Amrut\Downloads\Aadi_Proj\Train.csv')
my_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ### Exploratory Data Analysis( EDA)  and Insights

# %%
my_data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# #### `Insights`
# ~~~~~~~~~~~~~~~~~~~~~
# - 'Item_Identifier' has a pattern which might be the item or Product ID.
# - 'Item_Weight' is the weight of each product.
# - 'Item_Fat_Content' helps us to understand the FAT containing in each product.
# - 'Item_Visibility', looks like the probablity of the availablity of product in store.
# - Item_Type describes the which category product belongs to..
# - Item_MRP Price of the product.
# - Outlet_Identifier describes about availablity/purchase of the product at the outlet.
# - Outlet_Establishment_Year describes about year of launch of the outlet.
# - Outlet_Size describes about scale (how big) of the outlet.
# - Outlet_Location_Type describes in which category of cities it belongs.
# - Outlet_Type  describes in which category of outlet.
# - Item_Outlet_Sales decscribes the Sales made

# %%
len(my_data.columns)
# Out:
# 12

# %%
my_data.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
my_data.tail(5)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %% [markdown]
# #### `Insights`
# ~~~~~~~~~~~~~~~~~~~~~
#
# - From the above dataset we can observe there are different types of data

# %%
my_data.shape
# Out:
# (8523, 12)

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
my_data.isna()
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0               False        False             False            False
# 1               False        False             False            False
# 2               False        False             False            False
# 3               False        False             False            False
# 4               False        False             False            False
# ...               ...          ...               ...              ...
# 8518            False        False             False            False
# 8519            False        False             False            False
# 8520            False        False             False            False
# 8521            False        False             False            False
# 8522            False        False             False            False
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
my_data.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# #### `Insights`
# ~~~~~~~~~~
#
# - From the above dataset we can observe there are 8523 rows and 12 columns.
# - When compared with the data, we can see that there is non mismatch of the datatypes.
# - Also we can observe there are some missing values in dataset for the following columns..
#    - Item_Weight    1463
#    - Outlet_Size    2410
#    _______________________
#    - Total          3873  missing values

# %%
my_data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
my_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### `Insights`
#
# - As we can there are no duplicates present in the dataset

# %%
my_data[my_data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %% [markdown]
# #### `Insights`
#
#
# - From the above dataset we can observe there are no duplicate values.

# %%
my_data.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
for i in my_data:
    print(i)
# Out:
# Item_Identifier
# Item_Weight
# Item_Fat_Content
# Item_Visibility
# Item_Type
# Item_MRP
# Outlet_Identifier
# Outlet_Establishment_Year
# Outlet_Size
# Outlet_Location_Type
# Outlet_Type
# Item_Outlet_Sales

# %%
my_data['Outlet_Size'].nunique()
# Out:
# 3

# %%
for i in my_data:
    print('Unique values in ',i,' are ',my_data[i].nunique())
    print('**************************************************')
# Out:
# Unique values in  Item_Identifier  are  1559
# **************************************************
# Unique values in  Item_Weight  are  415
# **************************************************
# Unique values in  Item_Fat_Content  are  5
# **************************************************
# Unique values in  Item_Visibility  are  7880
# **************************************************
# Unique values in  Item_Type  are  16
# **************************************************
# Unique values in  Item_MRP  are  5938
# **************************************************
# Unique values in  Outlet_Identifier  are  10
# **************************************************
# Unique values in  Outlet_Establishment_Year  are  9
# **************************************************
# Unique values in  Outlet_Size  are  3
# **************************************************
# Unique values in  Outlet_Location_Type  are  3
# **************************************************
# ...

# %% [markdown]
# #### `Insights`
# ~~~~~~~~~~~~~~~~~~~~~
#
# - From the above dataset we can observe different types of data

# %%
my_data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
my_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #### `Insights`
#
# - Looking at above table we can see the Statsistical information of the data
# - Average weight of items is 12.8 units
# - Average MRP of items is 140.00 Rs and so onn...

# %% [markdown]
# ### Visualisations

# %%
my_data.shape
# Out:
# (8523, 12)

# %%
import sweetviz as sv

# %%
my_report = sv.analyze(my_data)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
plt.figure(figsize=(8,4))
my_data['Item_Fat_Content'].value_counts().plot(kind='bar', color='lightcoral')
plt.title('Item Fat Content Value Counts')
plt.xlabel('Item Fat Content')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### `Insights`
#
# - Low Fat items are more prevalent compared to Regular items

# %%
plt.figure(figsize=(8,4))
my_data['Item_Visibility'].plot(kind='hist', bins=20,color='mediumseagreen', edgecolor='black')
plt.title('Item Visibility Distribution')
plt.xlabel('Item Visibility')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### `Insights`
# - Asymetric visualisation,(Right skewed) as most of the data is towards the left
# - This suggests that there are a few items with significantly higher visibility than others.

# %%
plt.figure(figsize=(14,4))
my_data['Item_Type'].value_counts().plot(kind='bar', color='orange')
plt.title('Item Type Value Counts')
plt.xlabel('Item Type')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# #### `Insights`
#
# - We can observe the category of items sold.
# - Fruits,Vegetables,Snack Foods are the most common item types, while 'Seafood'is relatively rare.

# %%
plt.figure(figsize=(10,5))
my_data['Item_MRP'].plot(kind='hist', bins=20,color='#024155', edgecolor='black')
plt.title('Item MRP Distribution')
plt.xlabel('Item MRP')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### `Insights`
#
# - The distribution of item acoording to MRP,shows a pattern with multiple peaks.
# - This indicates different pricing across tiers.

# %%
plt.figure(figsize=(10,5))
my_data['Outlet_Identifier'].value_counts().plot(kind='bar',color='skyblue')
plt.title('Outlet Identifier Value Counts')
plt.xlabel('Outlet Identifier')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 6))
my_data['Outlet_Establishment_Year'].value_counts().sort_index().plot(kind='bar',color='#32ECD2')
plt.title('Outlet Establishment Year Value Counts')
plt.xlabel('Outlet Establishment Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### `Insights`
#
# - There are more outlets established in recent years compared to earlier years, with a peak in the mid-1980s

# %%
plt.figure(figsize=(8, 6))
my_data['Outlet_Size'].value_counts().plot(kind='bar')
plt.title('Outlet Size Value Counts')
plt.xlabel('Outlet Size')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### `Insights`
# - Medium-sized outlets are the most common.
# - followed by small and high sizes.

# %%
plt.figure(figsize=(8,5))
my_data['Outlet_Location_Type'].value_counts().plot(kind='bar',color='#EC32E3')
plt.title('Outlet Location Type Value Counts')
plt.xlabel('Outlet Location Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### `Insights`
#
# - 'Tier 3' locations have the most outlets as per the populaion/developed cities, followed by 'Tier 2' and 'Tier 1'

# %%
plt.figure(figsize=(10, 6))
my_data['Outlet_Type'].value_counts().plot(kind='bar',edgecolor='black')
plt.title('Outlet Type Value Counts')
plt.xlabel('Outlet Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### `Insights`
# - Supermarket Type1 is the most common outlet type, followed by Grocery Store, Supermarket Type3, and Supermarket Type2.

# %%
sns.pairplot(my_data)

# %%
corelation_mat = my_data.corr()
corelation_mat
# Out:
# C:\Users\Amrut\AppData\Local\Temp\ipykernel_24844\738918099.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corelation_mat = my_data.corr()
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# ...

# %%
sns.heatmap(corelation_mat,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Outliers detection

# %%
cpy_data = my_data

# %%
# Selecting only numerical columns
numerical_columns = my_data.select_dtypes(include=[np.number])
numerical_columns
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# ...

# %%
# Plotting box plots for each numerical column
plt.figure(figsize=(12, 8))
for i, column in enumerate(numerical_columns.columns):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(x=column, data=my_data, color='#EC326D')
    plt.title(f'Box Plot - {column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### `Insights`
#
# - There are several datapoints beyond the upper part of whisker,which indicates outliers

# %% [markdown]
# ### Feature Engineering

# %%
# Converting catergorical to numeric

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()

# %%
cpy_data.head(2)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDA15         9.30          Low Fat         0.016047        Dairy
# 1           DRC01         5.92          Regular         0.019278  Soft Drinks
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228

# %%
cpy_data['E_Item_Fat_Content'] =encoder.fit_transform(cpy_data['Item_Fat_Content'])

# %%
cpy_data['E_Item_Type'] =encoder.fit_transform(cpy_data['Item_Type'])
cpy_data['E_Outlet_Identifier'] =encoder.fit_transform(cpy_data['Outlet_Identifier'])
cpy_data['E_Outlet_Size'] =encoder.fit_transform(cpy_data['Outlet_Size'])
cpy_data['E_Outlet_Location_Type'] =encoder.fit_transform(cpy_data['Outlet_Location_Type'])
cpy_data['E_Outlet_Type'] =encoder.fit_transform(cpy_data['Outlet_Type'])

# %%
cpy_data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
processed_data = cpy_data.drop(['Item_Identifier','Item_Type','Item_Fat_Content','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type'],axis=1)

# %%
processed_data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales  E_Item_Fat_Content  E_Item_Type  E_Outlet_Identifier  \
# ...

# %%
processed_data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales  E_Item_Fat_Content  E_Item_Type  E_Outlet_Identifier  \
# ...

# %%
processed_data.isna().sum()
# Out:
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Item_Outlet_Sales            0
# E_Item_Fat_Content           0
# E_Item_Type                  0
# E_Outlet_Identifier          0
# E_Outlet_Size                0
# E_Outlet_Location_Type       0
# E_Outlet_Type                0
# dtype: int64

# %%
processed_data.fillna(processed_data.mean(), inplace=True)

# %%
processed_data.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Visibility              0
# Item_MRP                     0
# Outlet_Establishment_Year    0
# Item_Outlet_Sales            0
# E_Item_Fat_Content           0
# E_Item_Type                  0
# E_Outlet_Identifier          0
# E_Outlet_Size                0
# E_Outlet_Location_Type       0
# E_Outlet_Type                0
# dtype: int64

# %%
###  Splitiing the data into input and output features

# %%
X_unscaled = processed_data.drop(['Item_Outlet_Sales'],axis=1)
y_unscaled = processed_data['Item_Outlet_Sales']

# %%
X_unscaled.head(2)
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
#
#    E_Item_Fat_Content  E_Item_Type  E_Outlet_Identifier  E_Outlet_Size  \
# 0                   1            4                    9              1
# 1                   2           14                    3              1
#
#    E_Outlet_Location_Type  E_Outlet_Type
# 0                       0              1
# 1                       2              2

# %%
y_unscaled.head(2)
# Out:
# 0    3735.1380
# 1     443.4228
# Name: Item_Outlet_Sales, dtype: float64

# %%
# Splitiing the data into training and testing

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_unscaled, y_unscaled, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
model_lr = LinearRegression()
model_lr.fit(X_unscaled, y_unscaled)
# Out:
# LinearRegression()

# %%
# Making predictions

unscaled_linear_y_pred = model_lr.predict(X_test)

# %%
unscaled_linear_y_pred
# Out:
# array([ 880.66743568,  723.41709275,  853.39408849, ...,  310.60482361,
#        1160.35826923, 1647.32910037])

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
mse_unscaled_linear = mean_squared_error(y_test, unscaled_linear_y_pred)
mse_unscaled_linear
# Out:
# 1300857.5484863035

# %%
r2_unscaled_linear = r2_score(y_test, unscaled_linear_y_pred)

# %%
r2_unscaled_linear
# Out:
# 0.5213863594511229

# %% [markdown]
# ## `Insights`

# %% [markdown]
# - As we can observe the linear regression is giving accuracy of 52.13% which is very less.
# - This can be due to the data which is not scaled down.High range in numbers can efffect the model.
#
# - Lets build the model by scaling down the data and check the accuracy

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_scaled = scaler.fit_transform(X_unscaled)
X_scaled
# Out:
# array([[-0.84187169, -0.97073217,  1.74745381, ..., -0.74445778,
#         -1.36933384, -0.25265831],
#        [-1.64170589, -0.90811123, -1.48902325, ..., -0.74445778,
#          1.09156913,  1.00297245],
#        [ 1.09855449, -0.95691733,  0.01004021, ..., -0.74445778,
#         -1.36933384, -0.25265831],
#        ...,
#        [-0.53424315, -0.59978449, -0.89720755, ...,  0.26653866,
#         -0.13888236, -0.25265831],
#        [-1.33644372,  1.53287976, -0.60797692, ..., -0.74445778,
#          1.09156913,  1.00297245],
#        [ 0.45963367, -0.41193591, -1.05226104, ...,  0.26653866,
#         -1.36933384, -0.25265831]])

# %%
y_unscaled
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %% [markdown]
# ### Splitting train and test data on scaled data

# %%
X_train_scaled, X_test_scaled, y_train, y_test = train_test_split(X_scaled, y_unscaled, test_size=0.2, random_state=42)

# %% [markdown]
# #### Building model on scaled data

# %%
model_lr.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
scaled_linear_y_pred = model_lr.predict(X_test_scaled)
scaled_linear_y_pred
# Out:
# array([ 911.52977718,  722.83584883,  857.48479162, ...,  341.30735665,
#        1139.56665942, 1653.28844673])

# %%
mse_scaled_linear = mean_squared_error(y_test, scaled_linear_y_pred)
mse_scaled_linear
# Out:
# 1303773.302347676

# %%
r2_scaled_linear = r2_score(y_test, scaled_linear_y_pred)
r2_scaled_linear
# Out:
# 0.5203135905133096

# %% [markdown]
# `Insights`
#
# - Even after scaling down the data accuracy is not improved.

# %%
### Model using Randomforest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_scaled, y_unscaled)
# Out:
# RandomForestRegressor(random_state=42)

# %%
# Make predictions
y_pred_rf = model_rf.predict(X_test_scaled)

# Evaluate the model
mse_rf = mean_squared_error(y_test, y_pred_rf)
mse_rf
# Out:
# 168078.18469679405

# %%
# Evaluate the model
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_scaled_RF = r2_score(y_test, y_pred_rf)

# %%
print('The Mean squared error for Random Forest model is {}'.format(mse_rf))
print('The R squaared value for Random Forest model is {}'.format(r2_scaled_RF))
# Out:
# The Mean squared error for Random Forest model is 168078.18469679405
# The R squaared value for Random Forest model is 0.9381603989090231

# %% [markdown]
# #### The accuracy of model when built with Random Forest is 93.8%

# %%
model_rf_6 = RandomForestRegressor(n_estimators=100, random_state=42,max_depth=6)
model_rf_6.fit(X_scaled, y_unscaled)
# Out:
# RandomForestRegressor(max_depth=6, random_state=42)

# %%
y_pred_rf_6 = model_rf_6.predict(X_test_scaled)

# %%
mse_rf_6 = mean_squared_error(y_test, y_pred_rf_6)
r2_scaled_RF_6 = r2_score(y_test, y_pred_rf_6)

# %%
print('The Mean squared error for Random Forest model is {}'.format(mse_rf_6))
print('The R squaared value for Random Forest model is {}'.format(r2_scaled_RF_6))
# Out:
# The Mean squared error for Random Forest model is 995227.2108703689
# The R squaared value for Random Forest model is 0.6338343740079488

# %%
### Pruning the tree for chceking

# %%
model_rf_5 = RandomForestRegressor(n_estimators=100, random_state=42,max_depth=5)
model_rf_5.fit(X_scaled, y_unscaled)

y_pred_rf_5 = model_rf_5.predict(X_test_scaled)

mse_rf_5 = mean_squared_error(y_test, y_pred_rf_5)
r2_scaled_RF_5 = r2_score(y_test, y_pred_rf_5)

print('The Mean squared error for Random Forest model is {}'.format(mse_rf_5))
print('The R squaared value for Random Forest model is {}'.format(r2_scaled_RF_5))
# Out:
# The Mean squared error for Random Forest model is 1017206.5932553657
# The R squaared value for Random Forest model is 0.6257476836300977

# %%
## We can see model accuracy is decreasing with less depth.

# %% [markdown]
# ### Building model with XGBoost

# %%
from xgboost import XGBRegressor

# %%
xgb = XGBRegressor(objective='reg:squarederror', random_state=42)
xgb.fit(X_train, y_train)
y_pred_xgb = xgb.predict(X_test)

# %%
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
r2_xgb = r2_score(y_test, y_pred_xgb)

# %%
print('The Mean squared error for XG boost model is {}'.format(mse_xgb))
print('The R squaared value for XG boost model is {}'.format(r2_xgb))
# Out:
# The Mean squared error for XG boost model is 1306052.0051837529
# The R squaared value for XG boost model is 0.5194752064324601

# %% [markdown]
# #### Conclusion

# %%
print("Mean Sruared Error for all models")
print('------------------------------------------------------')
print("Unscaled Linear Regression MSE  :", mse_unscaled_linear)
print("Scaled Linear Regression MSE    :", mse_scaled_linear)
print("Random Forest MSE               : ",mse_rf)
print("Random Forest MSE: Depth as 5   :",mse_rf_5)
print("Random Forest MSE: Depth as 6   :",mse_rf_6)
print("XGBoost MSE                     :",mse_xgb)
# Out:
# Mean Sruared Error for all models
# ------------------------------------------------------
# Unscaled Linear Regression MSE  : 1300857.5484863035
# Scaled Linear Regression MSE    : 1303773.302347676
# Random Forest MSE               :  168078.18469679405
# Random Forest MSE: Depth as 5   : 1017206.5932553657
# Random Forest MSE: Depth as 6   : 995227.2108703689
# XGBoost MSE                     : 1306052.0051837529

# %%
print("Unscaled Linear Regression R squared  :", r2_unscaled_linear)
print("Scaled Linear Regression R squared    :", r2_scaled_linear)
print("Random Forest R squared               :",r2_scaled_RF)
print("Random Forest R squared: Depth as 5   :",r2_scaled_RF_5)
print("Random Forest R squared: Depth as 6   :",r2_scaled_RF_6)
print("XGBoost R squared                     :",r2_xgb)
# Out:
# Unscaled Linear Regression R squared  : 0.5213863594511229
# Scaled Linear Regression R squared    : 0.5203135905133096
# Random Forest R squared               : 0.9381603989090231
# Random Forest R squared: Depth as 5   : 0.6257476836300977
# Random Forest R squared: Depth as 6   : 0.6338343740079488
# XGBoost R squared                     : 0.5194752064324601
